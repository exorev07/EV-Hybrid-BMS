# %%
import pandas as pd

df = pd.read_csv('EV_Predictive_Maintenance_Dataset.csv')
print("First 10 rows: ")
df.head(10)
# Out:
# First 10 rows:
#              Timestamp       SoC       SoH  Battery_Voltage  Battery_Current  \
# 0  2020-01-01 00:00:00  0.826099  0.941338       210.163881       -22.753095
# 1  2020-01-01 00:15:00  0.064728  0.916059       364.000102       -27.701120
# 2  2020-01-01 00:30:00  0.873643  0.908020       388.855089       -36.646406
# 3  2020-01-01 00:45:00  0.853009  0.916476       370.570602       -37.609429
# 4  2020-01-01 01:00:00  0.947540  0.913206       390.011904       -14.275808
# 5  2020-01-01 01:15:00  0.993270  0.943180       382.518489       -38.870499
# 6  2020-01-01 01:30:00  0.859527  0.908637       244.796603       -20.959500
# 7  2020-01-01 01:45:00  0.142210  0.941402       373.584540       -18.235496
# 8  2020-01-01 02:00:00  0.853250  0.488862       350.179623       -11.735082
# 9  2020-01-01 02:15:00  0.932382  0.546485       386.496281       -12.438317
#
#    Battery_Temperature  Charge_Cycles  Motor_Temperature  Motor_Vibration  \
# 0            27.149201     149.190930          48.496049         0.369095
# 1            53.655101     171.702388          57.829492         1.449195
# 2            29.559090     191.617645          46.518363         1.859045
# 3            29.690283     111.881817          54.163681         0.381500
# 4            28.864338     163.774377          42.075978         0.433927
# 5            25.836633     134.243558          49.773682         0.471384
# 6            30.066757     161.997950          43.276789         1.902244
# 7            34.668815     123.777834          87.169614         1.331696
# 8            32.354467     118.385038          41.569869         0.216481
# 9            56.705313     192.589392          53.086604         0.413356
#
#    Motor_Torque  ...  Load_Weight  Driving_Speed  Distance_Traveled  \
# 0    113.435589  ...   741.754518     103.421162          66.232383
# 1    105.587160  ...   769.134035      46.041935           3.146238
# 2    119.610302  ...   917.262931      59.588422          79.909148
# 3    182.535625  ...   600.598736      44.222285           0.774000
# 4    173.298044  ...   613.153029      41.374684           2.872124
# 5    304.438211  ...   973.564344      41.668061           1.612127
# 6    184.879992  ...   863.085305      56.136629           0.871051
# 7    150.707053  ...   559.054599      53.054266           5.098734
# 8    161.536815  ...  1541.234219      52.842360           1.263134
# 9    167.141815  ...   757.444162      40.093487           0.628933
#
#    Idle_Time  Route_Roughness         RUL  Failure_Probability  \
# 0   0.520922         0.225970  260.503381                    0
# 1   0.844005         0.204350  212.813954                    0
# 2   0.992405         0.175125  273.394511                    0
# 3   0.007615         0.213264  229.508442                    0
# 4   0.771938         0.770257  257.302631                    1
# 5   0.474666         0.271970  245.951391                    0
# 6   0.768709         0.182309  286.391604                    0
# 7   0.216234         0.171064  201.976791                    0
# 8   0.375900         0.239868  202.718924                    1
# 9   0.040721         0.201295  299.994682                    0
#
#    Maintenance_Type         TTF  Component_Health_Score
# 0                 1  111.116697                0.852745
# 1                 2  179.229425                0.827616
# 2                 1  171.852663                0.876887
# 3                 0  165.221328                0.816290
# 4                 0  176.890659                0.744260
# 5                 0  166.304156                0.732834
# 6                 0  178.590599                0.840237
# 7                 0  126.753680                0.906106
# 8                 0  111.043514                0.835343
# 9                 1  164.295570                0.767494
#
# [10 rows x 30 columns]

# %%
# Dataset shape and basic info

print(f"Dataset Shape: {df.shape[0]:,} rows × {df.shape[1]} columns")
print("")
print("Column Names and Data Types:")
print(df.dtypes)

print("")
print("Missing Values:")
missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100
missing_df = pd.DataFrame({
    'Missing Count': missing,
    'Percentage': missing_pct.round(2)
})
print(missing_df[missing_df['Missing Count'] > 0] if missing_df['Missing Count'].sum() > 0 else "No missing values found!")

print("")
print("Duplicate Rows:")
duplicates = df.duplicated().sum()
print(f"Total duplicate rows: {duplicates:,}")

print("")
print("Statistical Summary:")
df.describe()
# Out:
# Dataset Shape: 175,393 rows × 30 columns
#
# Column Names and Data Types:
# Timestamp                  object
# SoC                       float64
# SoH                       float64
# Battery_Voltage           float64
# Battery_Current           float64
# Battery_Temperature       float64
# Charge_Cycles             float64
# Motor_Temperature         float64
# Motor_Vibration           float64
# Motor_Torque              float64
# Motor_RPM                 float64
# Power_Consumption         float64
# Brake_Pad_Wear            float64
# Brake_Pressure            float64
# Reg_Brake_Efficiency      float64
# Tire_Pressure             float64
# Tire_Temperature          float64
# Suspension_Load           float64
# Ambient_Temperature       float64
# Ambient_Humidity          float64
# Load_Weight               float64
# Driving_Speed             float64
# Distance_Traveled         float64
# Idle_Time                 float64
# Route_Roughness           float64
# RUL                       float64
# Failure_Probability         int64
# Maintenance_Type            int64
# TTF                       float64
# Component_Health_Score    float64
# dtype: object
#
# Missing Values:
# No missing values found!
#
# Duplicate Rows:
# Total duplicate rows: 0
#
# Statistical Summary:
#                  SoC            SoH  Battery_Voltage  Battery_Current  \
# count  175393.000000  175393.000000    175393.000000    175393.000000
# mean        0.779882       0.882219       352.713482       -47.892493
# std         0.291660       0.164805        55.246513        45.358339
# min         0.000006       0.400001       200.001095      -199.994036
# 25%         0.823508       0.911699       355.989733       -45.270093
# 50%         0.882380       0.941193       370.587405       -33.518350
# 75%         0.941148       0.970720       385.262527       -21.757595
# max         0.999999       0.999999       399.999314       -10.000173
#
#        Battery_Temperature  Charge_Cycles  Motor_Temperature  Motor_Vibration  \
# count        175393.000000  175393.000000      175393.000000    175393.000000
# mean             33.399346     217.685124          56.027332         0.523942
# std               8.655192     164.506573          15.447305         0.434352
# min              25.000010     100.000809          40.000182         0.200000
# 25%              27.948170     129.489301          45.872695         0.288583
# 50%              30.887664     158.901349          51.757365         0.376488
# 75%              33.826187     188.312590          57.678209         0.465118
# max              59.997570     699.996920          99.999997         1.999954
#
#         Motor_Torque      Motor_RPM  ...    Load_Weight  Driving_Speed  \
# count  175393.000000  175393.000000  ...  175393.000000  175393.000000
# mean      179.786407    2235.503735  ...     899.622755      58.254410
# std        76.767046    1188.119583  ...     384.992691      20.599544
# min       100.000039    1500.005873  ...     500.001439      40.000040
# 25%       129.469691    1646.972583  ...     647.083997      45.906363
# 50%       158.810055    1793.947006  ...     793.026812      51.776604
# 75%       188.025425    1941.249131  ...     940.973233      57.669053
# max       399.998498    5999.999833  ...    1999.971806     119.998280
#
#        Distance_Traveled      Idle_Time  Route_Roughness            RUL  \
# count      175393.000000  175393.000000    175393.000000  175393.000000
# mean           15.426523       1.554246         0.297452     216.366252
# std            25.663043       2.581281         0.240178      84.594382
# min             0.000059       0.000005         0.100000       0.000148
# 25%             2.937620       0.293588         0.159248     211.700417
# 50%             5.881970       0.586629         0.217891     241.127447
# 75%             8.790443       0.882060         0.276479     270.516993
# max            99.999640       9.999459         0.999997     299.999891
#
#        Failure_Probability  Maintenance_Type            TTF  \
# count        175393.000000     175393.000000  175393.000000
# mean              0.098818          0.498418     129.723870
# std               0.298418          0.865544      55.178580
# min               0.000000          0.000000       0.000009
# 25%               0.000000          0.000000     111.816152
# 50%               0.000000          0.000000     141.216309
# 75%               0.000000          1.000000     170.507963
# max               1.000000          3.000000     199.998920
#
#        Component_Health_Score
# count           175393.000000
# mean                 0.744438
# std                  0.265023
# min                  0.000005
# 25%                  0.735163
# 50%                  0.823212
# 75%                  0.911802
# max                  0.999999
#
# [8 rows x 29 columns]
